# %% [markdown]
# ### Models integration with openAi Gemini and Groq

# %%
import os
from dotenv import load_dotenv
load_dotenv


os.environ["Groq_Api_Key"]=os.getenv("Groq_Api_Key")

# %%
from langchain_groq import ChatGroq
model = ChatGroq(
    model="openai/gpt-oss-20b",
    api_key=os.getenv("Groq_Api_Key")
)
response1=model.invoke("who is telusko")
response1.content
# Out:
# '**Telusko** is a popular YouTube channel that focuses on programming, software development, and technology education. The channel is run by **Naveen Reddy** (often just called “Naveen”), a software engineer and educator.  \n\nKey points about Telusko:\n\n| Aspect | Details |\n|--------|---------|\n| **Content** | Tutorials on Java, Python, C/C++, Android, machine learning, data structures, algorithms, cloud services, and more. |\n| **Audience** | Beginners to intermediate programmers, students, and professionals looking to improve coding skills. |\n| **Style** | Clear, concise explanations, practical coding examples, and a mix of theoretical background with hands‑on projects. |\n| **Reach** | Over 2 million subscribers (as of 2024) and millions of views worldwide. |\n| **Other Platforms** | Active on Twitter, Instagram, and LinkedIn, often sharing coding tips and updates. |\n\nIf you’re looking to learn a particular language or technology, Telusko’s playlists are a good place to start, especially for Java and Python fundamentals.'

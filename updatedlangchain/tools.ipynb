# %% [markdown]
# ### Tools

# %%
import os
from langchain_groq import ChatGroq

model = ChatGroq(
    model="openai/gpt-oss-20b",
    api_key=os.getenv("Groq_Api_Key")
)

response=model.invoke("what do you know about mysuru")
response.content
# Out:
# '**Mysuru (Mysore)** – a brief snapshot\n\n| Category | Key facts |\n|----------|-----------|\n| **Location** | South‑central Karnataka, India; about 150\u202fkm southeast of Bengaluru. |\n| **Population** | ~1.1\u202fmillion (city proper), part of a larger urban agglomeration of ~1.6\u202fmillion. |\n| **Area** | Roughly 300\u202fkm². |\n| **Climate** | Tropical savanna (Köppen Aw). Mild, dry winters (Dec–Feb); hot, humid summers (Mar–Jun); moderate monsoon (Jul–Sep). |\n| **Language** | Kannada (official), with English, Hindi, and Tamil commonly spoken. |\n| **Economy** | 1. **Tourism** – heritage, cultural festivals, botanical gardens. 2. **Silk & textiles** – Mysore silk sarees. 3. **IT & services** – growing software parks. 4. **Agriculture** – banana, coconut, and spices. |\n| **History** | • Founded in 1399 by Devaraja Wodeyar. <br>• Became the capital of the Kingdom of Mysore under the Wodeyar dynasty. <br>• Came under British protection (1799–1947). <br>• Renamed Mysuru in 2014 to reflect the local Kannada pronunciation. |\n| **Cultural Highlights** | • **Mysore Palace** (Karnak Palace) – a fusion of Indo‑Sanskrit and Mughal architecture; the palace’s gold‑leafed ceilings and intricate murals are world‑famous. <br>• **Chamundi Hills** – home to the Chamundeshwari Temple and a panoramic view of the city. <br>• **Brindavan Gardens** – symmetrical terraces, musical fountains, and a lotus‑pool. <br>• **St. Philomena’s Church** – a Roman Catholic basilica with Gothic‑style arches. <br>• **Mysore Zoo (Sri Chamarajendra Zoological Gardens)** – one of the oldest in India, with a wide range of wildlife. <br>• **Karanji Lake & Butterfly Park** – a popular urban green space. |\n| **Festivals & Events** | • **Mysore Dasara** (September/October) – the grandest of India’s royal processions, featuring the “Rangoli” carpet, a parade of elephants, and the “Hannina Kambala” (water buffalo race). <br>• **Karnataka Rajyotsava** (Nov\u202f1) – state day celebrations. <br>• **Mysuru International Film Festival** – showcases regional cinema. |\n| **Cuisine** | • **Mysore Pak** – a rich, ghee‑laden sweet. <br>• **Mysore Masala Dosa** – a spiced potato filling with a distinct flavor. <br>• **Ragi Mudde** (finger millet balls) – staple of the local diet. <br>• **Mysore Bisi Bele Bath** – a spicy lentil–rice dish. |\n| **Transportation** | • **Airport** – Mysuru Airport (MYS) connects to Bengaluru, Chennai, Hyderabad, and other major cities. <br>• **Rail** – Mysuru Junction (MSR) is a major hub on the Bangalore–Mangalore line. <br>• **Road** – well‑connected via NH\u202f275 and NH\u202f766. |\n| **Notable People** | • **S. R. Ranganathan** – pioneer of library science. <br>• **M. V. Krishna Rao** – former Chief Minister of Karnataka. <br>• **K. S. Chithra** – playback singer. |\n| **Interesting Tidbits** | • The city’s name “Mysuru” literally means “the place of the banyan tree” (from Kannada “muru” – banyan). <br>• Mysuru is the only Indian city to have a “palace” that is still the residence of the ruling family (though now it’s largely a museum). <br>• The “Mysore Dasara” flag is 3\u202fm\u202f×\u202f9\u202fm and is the largest in the world. |\n\n---\n\n### Quick Takeaway\n\nMysuru is a blend of regal heritage, cultural vibrancy, and modern growth. Its iconic palace, the grand Dasara procession, and the world‑famous Mysore silk make it a must‑visit for history buffs and tourists alike, while its thriving IT and textile sectors keep the city moving forward. Whether you’re strolling through the Brindavan Gardens at sunset, sampling a plate of Mysore pak, or exploring the historic streets of the old city, Mysuru offers a unique, multi‑layered experience that captures the soul of Karnataka.'

# %%
from langchain.tools import tool

@tool
def get_weather(location:str)->str:
    """ Get weather at a location"""
    return f"its sunny in {location}"

model_with_tools=model.bind_tools([get_weather])

# %%
response=model_with_tools.invoke("whats the weather in mysuru")
response
for tool_call in response.tool_calls:
    print(f"Tool:{tool_call['name']}")
    print(f"Tool:{tool_call['args']}")
# Out:
# Tool:get_weather
# Tool:{'location': 'mysuru'}

# %%
model.profile
# Out:
# {'name': 'GPT OSS 20B',
#  'release_date': '2025-08-05',
#  'last_updated': '2026-05-27',
#  'open_weights': True,
#  'max_input_tokens': 131072,
#  'max_output_tokens': 65536,
#  'text_inputs': True,
#  'image_inputs': False,
#  'audio_inputs': False,
#  'video_inputs': False,
#  'text_outputs': True,
#  'image_outputs': False,
#  'audio_outputs': False,
#  'video_outputs': False,
#  'reasoning_output': True,
#  'tool_calling': True,
#  'structured_output': True,
#  'attachment': False,
#  'temperature': True}
